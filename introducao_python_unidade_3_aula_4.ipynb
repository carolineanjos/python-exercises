# %%
#visualização de dados
import matplotlib.pyplot as plt
import random

dados1 = random.sample(range(100), k=20)
dados2 = random.sample(range(100), k=20)

print(dados2)

plt.bar(dados1, dados2)
# Out:
# [16, 78, 12, 42, 75, 80, 73, 13, 81, 30, 15, 24, 95, 47, 56, 17, 51, 55, 58, 50]
# <BarContainer object of 20 artists>

# %%
import pandas as pd

dados = {
    'Produto':['A', 'B', 'C'],
    'quantidade_vendida': [20,30,21]
}

df = pd.DataFrame(dados)
df.plot(x='Produto', y='quantidade_vendida', kind='bar')
# Out:
# <Axes: xlabel='Produto'>

# %%
df.plot(x='Produto', y='quantidade_vendida', kind='pie')
# Out:
# <Axes: ylabel='quantidade_vendida'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='whitegrid')

df_tips = sns.load_dataset('tips')
print(df_tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))

sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[0])

sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[1], estimator=sum)

sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[2], estimator=len)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='whitegrid')

df_tips = sns.load_dataset('tips')

plt.figure(figsize=(8,5))
sns.barplot(x='time', y='total_bill', data=df, estimator=sum, errorbar=None, palette='Set2')
plt.xlabel('Período')
plt.ylabel('Total de Gastos')
plt.title('Total de Gastos por Período(ALmoço ou Jantar)')
plt.show()
# Out:
# /tmp/ipython-input-3559981334.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='time', y='total_bill', data=df_tips, estimator=sum, errorbar=None, palette='Set2')

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='time', y='total_bill', data=df_tips)
plt.xlabel('Período')
plt.ylabel('Média de Gastos')
plt.title('Média de Gastos por Período(ALmoço ou Jantar)')
plt.show()
